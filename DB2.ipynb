# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Student performance1 - Sheet1.csv")

# %%
df1=df
df2=df1
df3=df
df4=df

# %%
df
# Out:
#    Gender  math_score  reading score  writing score  placement score  \
# 0    male          71             60             74               66
# 1  female          61             68             65               72
# 2   male           61             61             78               61
# 3    male          78             75             76               62
# 4  female          62             68             69               75
# 5    male          61             66             76               63
# 6  female          69             74             71               73
# 7    male          60             62             67               77
# 8  female          70             79             69               63
#
#    club join year  placement offer count
# 0            2023                      1
# 1            2024                      1
# 2            2022                      2
# 3            2024                      2
# 4            2023                      1
# 5            2023                      2
# 6            2022                      1
# 7            2022                      1
# 8            2023                      1

# %%
df.isnull()
# Out:
#    Gender  math_score  reading score  writing score  placement score  \
# 0   False       False          False          False            False
# 1   False       False          False          False            False
# 2   False       False          False          False            False
# 3   False       False          False          False            False
# 4   False       False          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False       False          False          False            False
# 8   False       False          False          False            False
#
#    club join year  placement offer count
# 0           False                  False
# 1           False                  False
# 2           False                  False
# 3           False                  False
# 4           False                  False
# 5           False                  False
# 6           False                  False
# 7           False                  False
# 8           False                  False

# %%
df.isnull().sum()
# Out:
# Gender                   0
# math_score               0
# reading score            0
# writing score            0
# placement score          0
# club join year           0
# placement offer count    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['math_score', 'reading score', 'writing score', 'placement score',
#        'club jion year', 'placement offer count', 'Gender'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# math_score                True
# reading score             True
# writing score             True
# placement score           True
# club jion year           False
# placement offer count    False
# Gender                   False
# dtype: bool

# %%
pd.isnull(df["math_score"]).sum()
# Out:
# 1

# %%
df.notnull()
# Out:
#     math_score  reading score  writing score  placement score  club jion year  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6        False           True           True            False            True
# 7         True           True           True             True            True
# 8         True          False           True             True            True
# 9         True           True           True             True            True
# 10        True          False          False            False            True
# 11        True           True           True             True            True
# 12        True           True           True             True            True
# 13        True           True           True             True            True
# 14        True           True           True             True            True
# 15        True           True           True             True            True
#
#     placement offer count  Gender
# 0                    True    True
# 1                    True    True
# 2                    True    True
# 3                    True    True
# 4                    True    True
# 5                    True    True
# 6                    True    True
# 7                    True    True
# 8                    True    True
# 9                    True    True
# 10                   True    True
# 11                   True    True
# 12                   True    True
# 13                   True    True
# 14                   True    True
# 15                   True    True

# %%
df.notnull().sum()
# Out:
# math_score               15
# reading score            14
# writing score            15
# placement score          14
# club jion year           16
# placement offer count    16
# Gender                   16
# dtype: int64

# %%
df.head()
df1=df

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])
df
# Out:
#     math_score  reading score  writing score  placement score  club jion year  \
# 0         76.0           61.0           64.0             62.0            2023
# 1         77.0           66.0           74.0             67.0            2023
# 2         77.0           77.0           79.0             63.0            2022
# 3         80.0           64.0           66.0             76.0            2022
# 4         67.0           72.0           63.0             69.0            2023
# 5         74.0           65.0           67.0             73.0            2023
# 6          NaN           79.0           69.0              NaN            2023
# 7         72.0           77.0           80.0             60.0            2023
# 8         76.0            NaN           66.0             73.0            2022
# 9         75.0           79.0           77.0             75.0            2022
# 10        68.0            NaN            NaN              NaN            2023
# 11        61.0           70.0           74.0             76.0            2022
# 12        62.0           79.0           75.0             75.0            2022
# 13        66.0           69.0           62.0             67.0            2023
# 14        79.0           80.0           79.0             77.0            2023
# 15        67.0           64.0           64.0             72.0            2022
#
#     placement offer count  Gender
# 0                       1       0
# 1                       1       1
# 2                       1       1
# 3                       2       0
# 4                       1       1
# 5                       1       1
# 6                       1       1
# 7                       1       0
# 8                       1       1
# 9                       2       1
# 10                      1       0
# 11                      2       0
# 12                      2       1
# 13                      1       0
# 14                      2       1
# 15                      1       0

# %%
df.columns
# Out:
# Index(['math_score', 'reading score', 'writing score', 'placement score',
#        'club jion year', 'placement offer count', 'Gender'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# math_score               1
# reading score            2
# writing score            1
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df.describe()
# Out:
#        math_score  reading score  writing score  placement score  \
# count   15.000000      14.000000      15.000000        14.000000
# mean    71.800000      71.571429      70.600000        70.357143
# std      6.155137       6.824326       6.489552         5.705694
# min     61.000000      61.000000      62.000000        60.000000
# 25%     67.000000      65.250000      65.000000        67.000000
# 50%     74.000000      71.000000      69.000000        72.500000
# 75%     76.500000      78.500000      76.000000        75.000000
# max     80.000000      80.000000      80.000000        77.000000
#
#        club jion year  placement offer count     Gender
# count       16.000000              16.000000  16.000000
# mean      2022.562500               1.312500   0.562500
# std          0.512348               0.478714   0.512348
# min       2022.000000               1.000000   0.000000
# 25%       2022.000000               1.000000   0.000000
# 50%       2023.000000               1.000000   1.000000
# 75%       2023.000000               2.000000   1.000000
# max       2023.000000               2.000000   1.000000

# %%
df['reading score']
# Out:
# 0     61.0
# 1     66.0
# 2     77.0
# 3     64.0
# 4     72.0
# 5     65.0
# 6     79.0
# 7     77.0
# 8      NaN
# 9     79.0
# 10     NaN
# 11    70.0
# 12    79.0
# 13    69.0
# 14    80.0
# 15    64.0
# Name: reading score, dtype: float64

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# [8, 10]

# %%
df['reading score']=df['reading score'].fillna(60)

# %%
df['reading score']
# Out:
# 0     61.0
# 1     66.0
# 2     77.0
# 3     64.0
# 4     72.0
# 5     65.0
# 6     79.0
# 7     77.0
# 8     60.0
# 9     79.0
# 10    60.0
# 11    70.0
# 12    79.0
# 13    69.0
# 14    80.0
# 15    64.0
# Name: reading score, dtype: float64

# %%
df['reading score'].notnull().sum()
# Out:
# 16

# %%
df[df['math_score'].isnull()].index.tolist()
# Out:
# [6]

# %%
df['math_score']=df['math_score'].fillna(df['math_score'].mean())

# %%
df['math_score'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            1
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df[df['writing score'].isnull()].index.tolist()
# Out:
# [10]

# %%
df['writing score']=df['writing score'].fillna(df['writing score'].median())

# %%
df['writing score'].isnull().sum()
# Out:
# 0

# %%
df2.head()
# Out:
#    math_score  reading score  writing score  placement score  club jion year  \
# 0        76.0           61.0           64.0             62.0            2023
# 1        77.0           66.0           74.0             67.0            2023
# 2        77.0           77.0           79.0             63.0            2022
# 3        80.0           64.0           66.0             76.0            2022
# 4        67.0           72.0           63.0             69.0            2023
#
#    placement offer count  Gender
# 0                      1       0
# 1                      1       1
# 2                      1       1
# 3                      2       0
# 4                      1       1

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            0
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df[df['math_score'].isnull()].index.tolist()
# Out:
# []

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
df.replace(to_replace = np.nan, value = 80)
# Out:
#     math_score  reading score  writing score  placement score  club jion year  \
# 0         76.0           61.0           64.0             62.0            2023
# 1         77.0           66.0           74.0             67.0            2023
# 2         77.0           77.0           79.0             63.0            2022
# 3         80.0           64.0           66.0             76.0            2022
# 4         67.0           72.0           63.0             69.0            2023
# 5         74.0           65.0           67.0             73.0            2023
# 6         71.8           79.0           69.0             80.0            2023
# 7         72.0           77.0           80.0             60.0            2023
# 8         76.0           60.0           66.0             73.0            2022
# 9         75.0           79.0           77.0             75.0            2022
# 10        68.0           60.0           69.0             80.0            2023
# 11        61.0           70.0           74.0             76.0            2022
# 12        62.0           79.0           75.0             75.0            2022
# 13        66.0           69.0           62.0             67.0            2023
# 14        79.0           80.0           79.0             77.0            2023
# 15        67.0           64.0           64.0             72.0            2022
#
#     placement offer count  Gender
# 0                       1       0
# 1                       1       1
# 2                       1       1
# 3                       2       0
# 4                       1       1
# 5                       1       1
# 6                       1       1
# 7                       1       0
# 8                       1       1
# 9                       2       1
# 10                      1       0
# 11                      2       0
# 12                      2       1
# 13                      1       0
# 14                      2       1
# 15                      1       0

# %%
df2.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            0
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
#.deleting null values using dropna() method

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            0
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df3[df3['math_score'].isnull()].index.tolist()
# Out:
# []

# %%
df3[df3['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            0
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df[df['math_score'].isnull()].index.tolist()
# Out:
# []

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
df.replace(to_replace=np.nan, value = 80)
# Out:
#     math_score  reading score  writing score  placement score  club jion year  \
# 0         76.0           61.0           64.0             62.0            2023
# 1         77.0           66.0           74.0             67.0            2023
# 2         77.0           77.0           79.0             63.0            2022
# 3         80.0           64.0           66.0             76.0            2022
# 4         67.0           72.0           63.0             69.0            2023
# 5         74.0           65.0           67.0             73.0            2023
# 6         71.8           79.0           69.0             80.0            2023
# 7         72.0           77.0           80.0             60.0            2023
# 8         76.0           60.0           66.0             73.0            2022
# 9         75.0           79.0           77.0             75.0            2022
# 10        68.0           60.0           69.0             80.0            2023
# 11        61.0           70.0           74.0             76.0            2022
# 12        62.0           79.0           75.0             75.0            2022
# 13        66.0           69.0           62.0             67.0            2023
# 14        79.0           80.0           79.0             77.0            2023
# 15        67.0           64.0           64.0             72.0            2022
#
#     placement offer count  Gender
# 0                       1       0
# 1                       1       1
# 2                       1       1
# 3                       2       0
# 4                       1       1
# 5                       1       1
# 6                       1       1
# 7                       1       0
# 8                       1       1
# 9                       2       1
# 10                      1       0
# 11                      2       0
# 12                      2       1
# 13                      1       0
# 14                      2       1
# 15                      1       0

# %%
df2.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            0
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
# Deleting null values using dropna() method

# %%
df3.isnull().sum()
# Out:
# math_score               0
# reading score            0
# writing score            0
# placement score          2
# club jion year           0
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df3[df3['math_score'].isnull()].index .tolist()
# Out:
# []

# %%
df3[df3['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
#to drop rows with at least 1 null value
df3.dropna()
# Out:
#     math_score  reading score  writing score  placement score  club jion year  \
# 0         76.0           61.0           64.0             62.0            2023
# 1         77.0           66.0           74.0             67.0            2023
# 2         77.0           77.0           79.0             63.0            2022
# 3         80.0           64.0           66.0             76.0            2022
# 4         67.0           72.0           63.0             69.0            2023
# 5         74.0           65.0           67.0             73.0            2023
# 7         72.0           77.0           80.0             60.0            2023
# 8         76.0           60.0           66.0             73.0            2022
# 9         75.0           79.0           77.0             75.0            2022
# 11        61.0           70.0           74.0             76.0            2022
# 12        62.0           79.0           75.0             75.0            2022
# 13        66.0           69.0           62.0             67.0            2023
# 14        79.0           80.0           79.0             77.0            2023
# 15        67.0           64.0           64.0             72.0            2022
#
#     placement offer count  Gender
# 0                       1       0
# 1                       1       1
# 2                       1       1
# 3                       2       0
# 4                       1       1
# 5                       1       1
# 7                       1       0
# 8                       1       1
# 9                       2       1
# 11                      2       0
# 12                      2       1
# 13                      1       0
# 14                      2       1
# 15                      1       0

# %%
#to drop columns with at least 1 null value
df4.dropna(axis = 1)
# Out:
#     math_score  reading score  writing score  club jion year  \
# 0         76.0           61.0           64.0            2023
# 1         77.0           66.0           74.0            2023
# 2         77.0           77.0           79.0            2022
# 3         80.0           64.0           66.0            2022
# 4         67.0           72.0           63.0            2023
# 5         74.0           65.0           67.0            2023
# 6         71.8           79.0           69.0            2023
# 7         72.0           77.0           80.0            2023
# 8         76.0           60.0           66.0            2022
# 9         75.0           79.0           77.0            2022
# 10        68.0           60.0           69.0            2023
# 11        61.0           70.0           74.0            2022
# 12        62.0           79.0           75.0            2022
# 13        66.0           69.0           62.0            2023
# 14        79.0           80.0           79.0            2023
# 15        67.0           64.0           64.0            2022
#
#     placement offer count  Gender
# 0                       1       0
# 1                       1       1
# 2                       1       1
# 3                       2       0
# 4                       1       1
# 5                       1       1
# 6                       1       1
# 7                       1       0
# 8                       1       1
# 9                       2       1
# 10                      1       0
# 11                      2       0
# 12                      2       1
# 13                      1       0
# 14                      2       1
# 15                      1       0
